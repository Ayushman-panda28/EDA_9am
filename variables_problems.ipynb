# %%
# wap take 3 variables a,b,c 
# provide the value 
# find the average 

a=100
b=200
c=300
average=(a+b+c)/3
average
# Out:
# 200.0

# %%
# wap calculate area of circle 
# pi=3.14
# formula=pi*r*r

r=10
pi=3.14
formula =pi*r*r
formula
# Out:
# 314.0

# %%
bill_amount =1000
tip_amount=20
total_bill=bill_amount+tip_amount
total_bill
# Out:
# 1020

# %%
weight_value=101
pound=pound=weight_value*2.2
pound
# Out:
# 222.20000000000002

# %%
# wap to convert dollors indian pasia 
dollars=300
indian_pasia=80*dollars
indian_pasia
# Out:
# 24000
