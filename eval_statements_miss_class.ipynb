# %%
n1=int(input('enter the n1:')) # n1=int('100')
n2=int(input('enter the n2:')) # n2=int('200')
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 200
# 300

# %%
n1=float(input('enter the n1:')) # n1=int('100')
n2=float(input('enter the n2:')) # n2=int('200')
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 200
# 300.0

# %% [markdown]
# **Eval statement**
# - whwnever we want to use integer then we are applying **int**
#
# - similarly if we want to use decimal number we are applying **float**
#
# - there is one more operation is there : **eval**
#
# - **eval** wwill convert integer values to int type,decimal values to float type

# %%
n1=eval(input('enter the number1:'))
n2=eval(input('enter the number2:'))
n1+n2
# Out:
# enter the number1: 10
# enter the number2: 20
# 30

# %%
# 1
n1=eval(input('enter the number1:'))
n2=eval(input('enter the number2:'))
n3=eval(input('enter the number3:'))
avg=(n1+n2+n3)/3
round_avg=round(avg)
print(f'the avg of there number is :{round_avg}')
# Out:
# enter the number1: 100
# enter the number2: 200
# enter the number3: 20
# the avg of there number is :107

# %%
# 2
n1=eval(input('enter the number1:'))
n2=eval(input('enter the number2:'))
sub=(n1-n2)
mul=(n1*n2)
div=(n1/n2)
round_sub=round(sub)
round_mul=round(mul)
round_div=round(div)
print(f'the sub of two number is :{round_sub}')
print(f'the mul of two number is :{round_mul}')
print(f'the div of two number is :{round_div}')
# Out:
# enter the number1: 20
# enter the number2: 30
# the sub of two number is :-10
# the mul of two number is :600
# the div of two number is :1

# %%
pi=eval(input('enter the number:'))
r=eval(input('enter the number:'))
area_of_circle=pi*r*r
round_area_of_circle=round(area_of_circle)
print(f'the area of circle is :{round_area_of_circle}')
# Out:
# enter the number: 3.141
# enter the number: 20.4
# the area of circle is :1307

# %%
# 4
h=eval(input('enter the number:'))
b=eval(input('enter the number:'))
area_of_triangle=0.5*b*h
round_area_of_triangle=round(area_of_triangle)
print(f'the area of triangle is :{round_area_of_triangle}')
# Out:
# enter the number: 10.5
# enter the number: 30.4
# the area of triangle is :160

# %%
# 5
bill_amount=eval(input('enter the number:'))
tip_amount=eval(input('enter the number:'))
total_amount=bill_amount+tip_amount
round_total_amount=round(total_amount)
print(f'the total amount is :{round_total_amount}')
# Out:
# enter the number: 20000.38
# enter the number: 350.50
# the total amount is :20351

# %%
# 6
salary=eval(input('enter the number:'))
tax=eval(input('enter the number:'))
tax_amount=(salary*tax)/100
round_tax_amount=round(tax_amount)
print(f' tax amount is {round_tax_amount}')
# Out:
# enter the number: 20000.23
# enter the number: 12
#  tax amount is 2400

# %%
# 7
doller=eval(input('enter the number:'))
ruppes=doller*80
round_ruppes=round(ruppes)
print(f' the converted amount is {round_ruppes}')
# Out:
# enter the number: 200
#  the converted amount is 16000

# %%
# 8
pound=eval(input('enter the number:'))
kg=pound*2.2
round_kg=round(kg)
print(f'the converted amount is {round_kg}')
# Out:
# enter the number: 240.78
# the converted amount is 530
