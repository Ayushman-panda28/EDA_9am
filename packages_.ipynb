# %% [markdown]
# - variables
#
# - Data types
#
# - type casting
#
# - print statement
#
# - input and round
#
# - we perform the basic codes in 3 ways
#
#       - using proper variables
#       - using print statements
#       - using input and round

# %%
# Ramesh is a very good student
# he created a python code which do the addition of two number
# Ramesh felt that this code no one created till now
# Ramesh decided he wants to handover that to entire world
# He appraoched Anaconda organization
# Anaconda who ever installed your software
# my code should download automaticaly
# agreement
# addition.py file is available in my Laptop

# %%
#import <module_name>
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 #import <module_name>
# ----> 2 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
import random

# %%
import math

# %%
import time

# %%
import os

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
# ramesh is super excited 
# he created subtraction,divion,multiplication 
# anacond is asking that hand over the codes to me 
# what are the ways 
# method 1 - 
    # addition.py
    # subraction.py
   # multiplication.py
   # division.py

# %% [markdown]
# **Module**
#
# - module is a single python file
# - having variables , function , classes , methods
#
# **Packages**
#
# - package contains multiple python files
# - Assume that ramesh has created 4 python files
#
#        -  add.py
#        -  sub.py
#        -  mul.py
#        -  div.py
#
# - All these 4 python files can save into a package

# %%
math_function/
   add.py
   sub.py
   mul.py
   div.py

from math_functions import add
from math_functions import sub
from math_function  import mul
from math_function  import div 
from math_function  import add,sub,mul,div

# %% [markdown]
# - every python file can be consider as module
# - every module has
#    - variables
#    - function
# - some times we write these function under the **class**
# - if a function is writing under class we called as **method**
# - multiple methods will be available in a single python file

# %% [markdown]
# **Random**

# %%
import random 
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# step 1: import <module name> 
# step 2: dir(<module name>)
import <random> # wrong approch 
import random # right approch

# %%
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk_symlinks_as_files',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
# ...

# %%
dir('main')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir('file')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# - methods under a module is also called as **attribute**
# - random is a module
#    - randint is a method or attribute
#    - random is a method or attribute
#
#  - Every method purpose is different and use case is different
#
#  - If we want to call method or attribute , we need to call using module

# %%
import random 
random.randint
# attribute randint available
# i missied the brackets then bound method is coming
# Out:
# <bound method Random.randint of <random.Random object at 0x0000025BB6B051B0>>

# %% [markdown]
# **whenever we miss the bracket it will indicates two ways**
#
# - bound method
#
# - function

# %%
import random 
random.virat
# no attribute name virat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 import random
# ----> 2 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_12',
#  '_16',
#  '_17',
#  '_19',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'math',
#  'open',
#  'os',
#  'quit',
#  'random',
#  'time']

# %%
#step1: import <module name >
# step2: dir <module name >
# step3: module_name.method_name 
# when we do step 3 we sometime get the answer , we will get an indication bound method or function

# %%
import random
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x0000025BB6B051B0>>

# %%
# what is the work randint will do 
help (random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,10)
# Out:
# 6

# %%
#step1: import <module name >
# step2: dir <module name >
# step3: modulename.methodname 
# step4: help(modulename.methodname)
# apply the use case

# %%
import random
dir(random)
random.randint
help(random.randint)
random.randint(1,10)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.
# 5

# %%
import random
dir(random)
random.random
help(random.random)
random.random()
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).
# 0.891918799226206

# %%
# module   method 
# random    randint 
# random    choice
# random   shuffel

# %%
import random 
dir(random)
random.choice
help(random.choice)
l=[10,20,30,40]
random.choice(l)
# Out:
# Help on method choice in module random:
#
# choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.
# 10

# %%
import random 
dir(random)
random.randint
help(random.randint)
random.randint(1,20)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.
# 9

# %%
import random
dir(random)
random.shuffle
help(random.shuffle)
x=[1,2,3,4]
random.shuffle(x)
x
# Out:
# Help on method shuffle in module random:
#
# shuffle(x) method of random.Random instance
#     Shuffle list x in place, and return None.
# [1, 2, 3, 4]

# %%
import math 
dir(math)
math.e
# Out:
# 2.718281828459045

# %%
import math
dir(math)
math.pi
# Out:
# 3.141592653589793

# %%
import math
dir(math)
math.sqrt(9)
# Out:
# 3.0

# %%
import math
dir(math)
math.pow(2,4)
# Out:
# 16.0

# %%
import math
dir(math)
math.sin(2)
# Out:
# 0.9092974268256817

# %%
import math
dir(math)
math.ceil(2.6000089866756)
# Out:
# 3

# %%
import time
dir(time)
time.sleep(5)
print('hello Boss')
# it jupiter notebook will start after 5 sec
# Out:
# hello Boss

# %%
import os 
dir(os)
os.getcwd()
# Out:
# 'C:\\Users\\ayush\\OneDrive\\Documents\\naresh IT\\python_sessions'

# %%
import os
dir(os)
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'demo1.ipynb',
#  'eval_statements_miss_class.ipynb',
#  'packages_.ipynb',
#  'print_statements_session_3.ipynb',
#  'print_statement_assignment.ipynb',
#  'sessions_1_variables .ipynb',
#  'session_1.ipynb',
#  'session_2.ipynb',
#  'session_3.ipynb',
#  'session_3_error_of_prints.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'variables_problems.ipynb']

# %%
import time 
start=time.time()  # random 
time.sleep(5)
print('hello')
end=time.time()    # random 
end-start
# Out:
# hello
# 5.001086235046387

# %%
os.makedirs('virat')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 os.makedirs('virat')
#
# File ~\anaconda3\Lib\os.py:228, in makedirs(name, mode, exist_ok)
#     226         return
#     227 try:
# --> 228     mkdir(name, mode)
#     229 except OSError:
#     230     # Cannot rely on checking for EEXIST, since the operating system
#     231     # could give priority to other errors like EACCES or EROFS
#     232     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'virat'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# **Date=19nov_class**

# %%
import string
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
import string
dir(string)
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import string
dir(string)
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
import string
dir(string)
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
import string
dir(string)
string.digits
# Out:
# '0123456789'

# %%
import string
string.hexdigits
# Out:
# '0123456789abcdefABCDEF'

# %%
import random 
random.randint(10,20)
# Out:
# 17

# %%
from random import randint
randint(10,20)
# Out:
# 10

# %%
import random 
random
# Out:
# <module 'random' from 'C:\\Users\\ayush\\anaconda3\\Lib\\random.py'>

# %%
import flask

# %%
import streamlit

# %%
import cv2

# %%
import langchain

# %%
import langgraph

# %%
import tensorflow
