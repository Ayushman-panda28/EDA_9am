# %% [markdown]
# **print statement**
# - print is a inbuild function used to prints the outputs:
# - we always work toward only one end goal: **customer sastisfaction**
# - clint does not know the python function
# - what ever we want to show the output we need tho display clearly
# - question yourself : **Am i showing output properly**

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the summation of 100 and 200 is 300') # first trigger
# Out:
# the addition of 100 and 200 is 300
# the summation of 100 and 200 is 300

# %%
# the writeup is in string formate == quotes (red)
# 1000 and 2000 or 100 200 
# stored in variable n1 and n2 (black)

# %%
n1=100
n2=200
add=n1+n2
print('the addition of', n1, 'and', n2 ,'is', add) # slovedddddddd
# Out:
# the addition of 100 and 200 is 300

# %%
n1=100
n2=200
add=n1+n2
print('the addition of n1 and n2 is add')# 2nd trigger
# Out:
# the addition of n1 and n2 is add

# %%
# name 
# age 
# place 
# i am python 10 years old coming from hyderabad 

name='Ayushman panda'
age=22
place='pune'
print('I am',name,age,'years old comming from',place)
# Out:
# I am Ayushman panda 22 years old comming from pune

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the addition of {} and {} is {}')
print('the addition of {} and {} is {}'.format(n1,n2,add))
# Out:
# the addition of 100 and 200 is 300
# the addition of {} and {} is {}
# the addition of 100 and 200 is 300

# %%
name='Ayushman panda'
age=22
place='pune'
print('I am {} {} years old from {}'.format(name,age,place))
# Out:
# I am Ayushman panda 22 years old from pune

# %% [markdown]
# **f-string**

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print(f'the addition of {n1} and {n2} is {add}') # f-string used
# Out:
# the addition of 100 and 200 is 300
# the addition of 100 and 200 is 300

# %%
name='Ayushman panda'
age=22
place='pune'
print(f'I am {name} {age} years old from {place}')
# Out:
# I am Ayushman panda 22 years old from pune

# %%
n1=100 
n2=200 
a=n1-n2
b=n1*n2
c=n1/n2
print(f'the sub of {n1} and {n2} is {a}')
print(f'the mul of {n1} and {n2} is {b}')
print(f'the div of {n1} and {n2} is {c}')
# Out:
# the sub of 100 and 200 is -100
# the mul of 100 and 200 is 20000
# the div of 100 and 200 is 0.5

# %%
pi=3.14 
r=10
area_of_circle=pi*r*r
print(f'the area_of_circle is {area_of_circle}')
# Out:
# the area_of_circle is 314.0

# %%
b=10
h=5
area_of_triangle=0.5*b*h
print(f'area_of_triangle is {area_of_triangle}')
# Out:
# area_of_triangle is 25.0

# %%
a=10
b=20
c=30
avg=(a+b+c)/3
print(f'the average of 3 numbers is {avg}')
# Out:
# the average of 3 numbers is 20.0

# %%
bill_amount=1000
tip_amount=10
total_amount=bill_amount+tip_amount
print(f'the total amount is {total_amount}')
# Out:
# the total amount is 1010

# %%
salary=20000
tax=18
tax_amount=salary*tax/100
print(f'The tax amount of tha salary is {tax_amount}')
# Out:
# The tax amount of tha salary is 3600.0

# %%
dollar=1000
rupees=dollar*80
print(f'the {dollar}$ is {rupees}rupees')
# Out:
# the 1000$ is 80000rupees

# %%
pound=200
kg=pound*2.2
print(f'the {pound} pound converted into {kg}kg')
# Out:
# the 200 pound converted into 440.00000000000006kg
