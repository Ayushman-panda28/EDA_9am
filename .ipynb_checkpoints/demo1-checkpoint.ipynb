# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a=10
b=20
a
b
# Out:
# 20

# %%
a=10
b=20
print(a)
b
# Out:
# 10
# 20

# %%
a=10
b=20
a,b
# Out:
# (10, 20)

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
a=10
b=20
print(a),print(b)
# Out:
# 10
# 20
# (None, None)

# %%
a=10
b=20
print(a,b)
# Out:
# 10 20

# %%
#hello today i am learning python

# %%
"hello today i am learning python"
# Out:
# 'hello today i am learning python'

# %% [markdown]
# hello today i am learning python it is very intresting

# %%
esc+m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 esc+m
#
# NameError: name 'esc' is not defined

# %% [markdown]
# hello

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %% [markdown]
# ### python

# %% [markdown]
# - squar brackets indicates the cell is in code mode
#
# - when square brackets is not there it is in markedown mode
#
# - code mode is used to write the coding part
#
# - markdown is used to documentation of entire development like a book

# %%
# these are the keyword used when hifen to allocate them put gap between them otherwise it will not print

# %% [markdown]
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20240319155102/what-is-ai-artificial-intelligence.webp" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1000px; height: 100px; margin: 0px; width: 213px;" alt="What is AI? - GeeksforGeeks" jsname="kn3ccd">
